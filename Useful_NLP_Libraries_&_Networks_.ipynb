# %% [markdown]
# # Useful NLP Libraries & Networks Theory Questions

# %% [markdown]
# Question 1: Compare and contrast NLTK and spaCy in terms of features, ease of use, and performance.
#
#   - Answer:
# NLTK is mainly designed for education and research, offering many NLP algorithms and linguistic resources.
# spaCy focuses on industrial applications with faster processing and pre-trained pipelines.
# NLTK is easier for learning NLP concepts, while spaCy is simpler for building real-world NLP applications.
# In terms of performance, spaCy is much faster and more efficient than NLTK for large datasets.
#
# Question 2: What is TextBlob and how does it simplify common NLP tasks like sentiment analysis and translation?
#
#   - Answer:
# TextBlob is a Python library built on top of NLTK and Pattern.
# It simplifies NLP tasks such as sentiment analysis, noun phrase extraction, spell correction, and translation using simple APIs.
# Developers can perform complex NLP tasks with very little code.
# It is beginner-friendly and widely used for rapid NLP prototyping.
#
# Question 3: Explain the role of Stanford NLP in academic and industry NLP projects.
#
#   - Answer:
# Stanford NLP Group provides advanced NLP tools and research models widely used in academia and industry.
# It offers features like parsing, named entity recognition, sentiment analysis, and dependency analysis.
# Researchers use it for language studies, while industries apply it in chatbots, translation systems, and search engines.
# Its high accuracy and deep linguistic analysis make it highly valuable.
#
# Question 4: Describe the architecture and functioning of a Recurrent Neural Network (RNN).
#
#   - Answer:
# A Recurrent Neural Network (RNN) is designed to process sequential data such as text or speech.
# It contains loops that allow information from previous inputs to influence current outputs.
# The hidden state acts as memory, storing past information while processing sequences step by step.
# RNNs are commonly used in language modeling, machine translation, and speech recognition.
#
# Question 5: What is the key difference between LSTM and GRU networks in NLP applications?
#
#   - Answer:
# Long Short-Term Memory uses three gates: input, forget, and output gates.
# Gated Recurrent Unit uses only reset and update gates, making it simpler.
# LSTMs are better for handling long-term dependencies, while GRUs train faster with fewer parameters.
# GRUs are computationally efficient, whereas LSTMs are generally more powerful for complex tasks.
#
# Question 10: Explain how LSTM/GRU with spaCy or Stanford NLP can be used in a mental health chatbot.
#
#   - Answer:
# A mental health chatbot can use spaCy or Stanford NLP for preprocessing tasks such as tokenization, lemmatization, entity recognition, and intent detection.
# LSTM or GRU networks can analyze sequential user conversations to understand emotions, context, and user intent.
# The architecture includes text preprocessing, embedding layers, recurrent neural networks, response generation, and sentiment analysis modules.
# Ethical considerations include user privacy, data security, bias reduction, emotional sensitivity, and directing high-risk users to professional human support.

# %% [markdown]
# # Practical Questions

# %%
# Question 6: Python program using TextBlob for sentiment analysis.

from textblob import TextBlob

text = """
I had a great experience using the new mobile banking app.
The interface is intuitive, and customer support was quick
to resolve my issue. However, the app did crash once during
a transaction, which was frustrating.
"""

blob = TextBlob(text)

polarity = blob.sentiment.polarity
subjectivity = blob.sentiment.subjectivity

print("Polarity Score:", polarity)
print("Subjectivity Score:", subjectivity)
# Out:
# Polarity Score: 0.21742424242424244
# Subjectivity Score: 0.6511363636363636

# %%
# Question 7: String tokenization and frequency distribution using Python and NLTK.

import nltk
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist

text = """
Natural Language Processing (NLP) is a fascinating field that
combines linguistics, computer science, and artificial intelligence.
It enables machines to understand, interpret, and generate human language.
Applications of NLP include chatbots, sentiment analysis,
and machine translation. As technology advances,
the role of NLP in modern solutions is becoming increasingly critical.
"""

tokens = word_tokenize(text)

print("Tokens:")
print(tokens)

freq_dist = FreqDist(tokens)

print("\nFrequency Distribution:")
print(freq_dist.most_common(10))
# Out:
# Tokens:
# ['Natural', 'Language', 'Processing', '(', 'NLP', ')', 'is', 'a', 'fascinating', 'field', 'that', 'combines', 'linguistics', ',', 'computer', 'science', ',', 'and', 'artificial', 'intelligence', '.', 'It', 'enables', 'machines', 'to', 'understand', ',', 'interpret', ',', 'and', 'generate', 'human', 'language', '.', 'Applications', 'of', 'NLP', 'include', 'chatbots', ',', 'sentiment', 'analysis', ',', 'and', 'machine', 'translation', '.', 'As', 'technology', 'advances', ',', 'the', 'role', 'of', 'NLP', 'in', 'modern', 'solutions', 'is', 'becoming', 'increasingly', 'critical', '.']
#
# Frequency Distribution:
# [(',', 7), ('.', 4), ('NLP', 3), ('and', 3), ('is', 2), ('of', 2), ('Natural', 1), ('Language', 1), ('Processing', 1), ('(', 1)]

# %%
# Question 8: Basic LSTM model in Keras for text classification.

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
import numpy as np

texts = [
    "I love this project",
    "This is an amazing experience",
    "I hate waiting in line",
    "This is the worst service",
    "Absolutely fantastic!"
]

labels = [1, 1, 0, 0, 1]

tokenizer = Tokenizer()
tokenizer.fit_on_texts(texts)

sequences = tokenizer.texts_to_sequences(texts)

padded_sequences = pad_sequences(sequences, maxlen=5)

labels = np.array(labels)

model = Sequential([
    Embedding(input_dim=50, output_dim=8, input_length=5),
    LSTM(16),
    Dense(1, activation='sigmoid')
])

model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

model.fit(padded_sequences, labels, epochs=10)
model.summary()
# Out:
# Epoch 1/10
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.6000 - loss: 0.6929
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6000 - loss: 0.6915
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.6000 - loss: 0.6901
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.6000 - loss: 0.6887
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.6000 - loss: 0.6873
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.6000 - loss: 0.6859
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.6000 - loss: 0.6844
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.6000 - loss: 0.6830
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.6000 - loss: 0.6815
# Epoch 10/10
# ...

# %%
# Question 9: spaCy NLP pipeline with tokenization, lemmatization, and entity recognition.

import spacy

nlp = spacy.load("en_core_web_sm")

text = """
Homi Jehangir Bhabha was an Indian nuclear physicist who played a key role
in the development of India’s atomic energy program.
He was the founding director of the Tata Institute of Fundamental Research (TIFR)
and was instrumental in establishing the Atomic Energy Commission of India.
"""

doc = nlp(text)

print("Tokens and Lemmas:")
for token in doc:
    print(token.text, "->", token.lemma_)

print("\nNamed Entities:")
for ent in doc.ents:
    print(ent.text, "-", ent.label_)
# Out:
# Tokens and Lemmas:
#
#  ->
#
# Homi -> Homi
# Jehangir -> Jehangir
# Bhabha -> Bhabha
# was -> be
# an -> an
# Indian -> indian
# nuclear -> nuclear
# physicist -> physicist
# who -> who
# played -> play
# a -> a
# key -> key
# role -> role
#
#  ->
#
# in -> in
# the -> the
# development -> development
# of -> of
# India -> India
# ’s -> ’s
# atomic -> atomic
# energy -> energy
# program -> program
# . -> .
#
#  ->
#
# He -> he
# was -> be
# the -> the
# founding -> found
# director -> director
# of -> of
# the -> the
# Tata -> Tata
# Institute -> Institute
# of -> of
# Fundamental -> Fundamental
# Research -> Research
# ( -> (
# TIFR -> TIFR
# ) -> )
#
#  ->
#
# and -> and
# was -> be
# instrumental -> instrumental
# in -> in
# establishing -> establish
# the -> the
# Atomic -> Atomic
# Energy -> Energy
# Commission -> Commission
# of -> of
# India -> India
# . -> .
#
#  ->
#
#
# Named Entities:
# Indian - NORP
# India - GPE
# the Tata Institute of Fundamental Research - ORG
# ...
